# %%
import pandas as pd
import json
import os 
import glob
from textblob import TextBlob
import sys
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os
import nltk
#import pycountry
import re
import string
from wordcloud import WordCloud, STOPWORDS
from PIL import Image
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from langdetect import detect
from nltk.stem import SnowballStemmer
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from sklearn.feature_extraction.text import CountVectorizer

# %% [markdown]
# **1. Functions that will be used throughout the notebook**

# %%
def openData(path):
    with open(path) as f:
        data = json.load(f)
    return data 


def rename_column(oldName, newName, df):
    """This function renames columns of a pandas dataframe. 
    Parameters:
        oldName: Name of the old column in which you want to change 
        newName: Text in which you want the column to be renamed
        oldName2: Name of the old column in which you want to change 
        newName2: Text in which you want the column to be renamed
        df: The dataframe you want to rename columns in. 
    
    Returns a dataframe with new column names. 
    """
    New = df.rename(columns={oldName: newName})
    return New

def get_year(df):
    df["year"] = df['created_at'].astype(str).str[:4]
    return df

def drop(df, column):
    df = df.drop([column], axis=1)
    return df 

def get_month(df):
    df['Month'] = df['created_at'].str[5:7]
    return df

def get_day(df):
    df['Day'] = df['created_at'].str[8:10]
    return df

def DayTweeted(df):
    df['Date'] = df['Date Tweeted'].str[0:10]
    return df

# %% [markdown]
# **2. Calling in data from postman collected on October 25th**

# %%
data_1 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 10-25/Bitcon1.json")
data_2 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 10-25/Bitcoin2.json")
data_3 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 10-25/Bitcoin3.json")
data_4 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 10-25/Bitcoin4.json")
data_5 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 10-25/Bitcoin5.json")
data_6 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 10-25/Bitcoin6.json")
data_7 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 10-25/Bitcoin7.json")
data_8 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 10-25/Bitcoin8.json")
data_9 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 10-25/Bitcoin9.json")
data_10 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 10-25/Bitcoin10.json")
data_11 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 10-25/Bitcoin11.json")
data_12= openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 10-25/Bitcoin12.json")
data_13 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 10-25/Bitcoin13.json")
data_14 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 10-25/Bitcoin14.json")
data_15 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 10-25/Bitcoin15.json")
data_16 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 10-25/Bitcoin16.json")
data_17 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 10-25/Bitcoin17.json")
data_18 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 10-25/Bitcoin18.json")
data_19 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 10-25/Bitcoin19.json")
data_20 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 10-25/Bitcoin20.json")
data_21 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 10-25/Bitcoin21.json")
data_22 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 10-25/Bitcoin22.json")
data_23= openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 10-25/Bitcoin23.json")
data_24 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 10-25/Bitcoin24.json")
data_25 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 10-25/Bitcoin25.json")
data_26 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 10-25/Bitcoin26.json")
data_27= openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 10-25/Bitcoin27.json")
data_28 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 10-25/Bitcoin28.json")
data_29 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 10-25/Bitcoin29.json")
data_30 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 10-25/Bitcoin30.json")
data_31 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 10-25/Bitcoin31.json")
data_32 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 10-25/Bitcoin32.json")
data_33 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 10-25/Bitcoin33.json")
data_34 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 10-25/Bitcoin34.json")
data_35 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 10-25/Bitcoin35.json")
data_36 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 10-25/Bitcoin36.json")
data_37= openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 10-25/Bitcoin37.json")
data_38 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 10-25/Bitcoin38.json")
data_39 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 10-25/Bitcoin39.json")
data_40 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 10-25/Bitcoin40.json")
data_41 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 10-25/Bitcoin41.json")
data_42 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 10-25/Bitcoin42.json")
data_43 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 10-25/Bitcoin43.json")
data_44 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 10-25/Bitcoin44.json")
data_45 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 10-25/Bitcoin45.json")
data_46 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 10-25/Bitcoin46.json")
data_47 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 10-25/Bitcoin47.json")
data_48= openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 10-25/Bitcoin48.json")
data_49 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 10-25/Bitcoin49.json")
data_50 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 10-25/Bitcoin50.json")
data_51 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 10-25/Bitcoin51.json")
data_52 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 10-25/Bitcoin52.json")
data_53 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 10-25/Bitcoin53.json")
data_54 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 10-25/Bitcoin54.json")
data_55 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 10-25/Bitcoin55.json")
data_56 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 10-25/Bitcoin56.json")
data_57 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 10-25/Bitcoin57.json")
data_58 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 10-25/Bitcoin58.json")
data_59 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 10-25/Bitcoin59.json")
data_60 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 10-25/Bitcoin60.json")
data_61 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 10-25/Bitcoin61.json")
data_62= openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 10-25/Bitcoin62.json")
data_63 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 10-25/Bitcoin63.json")
data_64 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 10-25/Bitcoin64.json")
data_65 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 10-25/Bitcoin65.json")
data_66 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 10-25/Bitcoin66.json")
data_67 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 10-25/Bitcoin67.json")
data_68 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 10-25/Bitcoin68.json")
data_69 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 10-25/Bitcoin69.json")
data_70 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 10-25/Bitcoin70.json")
data_71 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 10-25/Bitcoin71.json")
data_72 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 10-25/Bitcoin72.json")
data_73= openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 10-25/Bitcoin73.json")
data_74 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 10-25/Bitcoin74.json")
data_75 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 10-25/Bitcoin75.json")
data_76 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 10-25/Bitcoin76.json")
data_77 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 10-25/Bitcoin77.json")
data_78 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 10-25/Bitcoin78.json")
data_79 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 10-25/Bitcoin79.json")
data_80 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 10-25/Bitcoin80.json")
data_81 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 10-25/Bitcoin81.json")
data_82 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 10-25/Bitcoin82.json")
data_83 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 10-25/Bitcoin83.json")
data_84 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 10-25/Bitcoin84.json")
data_85 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 10-25/Bitcoin85.json")
data_86 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 10-25/Bitcoin86.json")
data_87= openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 10-25/Bitcoin87.json")
data_88 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 10-25/Bitcoin88.json")
data_89 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 10-25/Bitcoin89.json")
data_90 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 10-25/Bitcoin90.json")
data_91 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 10-25/Bitcoin91.json")
data_92 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 10-25/Bitcoin92.json")
data_93 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 10-25/Bitcoin93.json")
data_94 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 10-25/Bitcoin94.json")
data_95 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 10-25/Bitcoin95.json")
data_96 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 10-25/Bitcoin96.json")
data_97 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 10-25/Bitcoin97.json")
data_98= openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 10-25/Bitcoin98.json")
data_99 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 10-25/Bitcoin99.json")
data_100 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 10-25/Bitcoin100.json")

# %% [markdown]
# **3. Getting just the data needed from the postman collection**

# %%
data_1 = pd.DataFrame(data_1['data'])
data_2 = pd.DataFrame(data_2['data'])
data_3 = pd.DataFrame(data_3['data'])
data_4 = pd.DataFrame(data_4['data'])
data_5 = pd.DataFrame(data_5['data'])
data_6 = pd.DataFrame(data_6['data'])
data_7 = pd.DataFrame(data_7['data'])
data_8 = pd.DataFrame(data_8['data'])
data_9 = pd.DataFrame(data_9['data'])
data_10 = pd.DataFrame(data_10['data'])
data_11 = pd.DataFrame(data_11['data'])
data_12 = pd.DataFrame(data_12['data'])
data_13 = pd.DataFrame(data_13['data'])
data_14 = pd.DataFrame(data_14['data'])
data_15 = pd.DataFrame(data_15['data'])
data_16 = pd.DataFrame(data_16['data'])
data_17 = pd.DataFrame(data_17['data'])
data_18 = pd.DataFrame(data_18['data'])
data_19 = pd.DataFrame(data_19['data'])
data_20 = pd.DataFrame(data_20['data'])
data_21 = pd.DataFrame(data_21['data'])
data_22 = pd.DataFrame(data_22['data'])
data_23 = pd.DataFrame(data_23['data'])
data_24 = pd.DataFrame(data_24['data'])
data_25 = pd.DataFrame(data_25['data'])
data_26 = pd.DataFrame(data_26['data'])
data_27 = pd.DataFrame(data_27['data'])
data_28 = pd.DataFrame(data_28['data'])
data_29 = pd.DataFrame(data_29['data'])
data_30 = pd.DataFrame(data_30['data'])
data_31 = pd.DataFrame(data_31['data'])
data_32= pd.DataFrame(data_32['data'])
data_33 = pd.DataFrame(data_33['data'])
data_34 = pd.DataFrame(data_34['data'])
data_35 = pd.DataFrame(data_35['data'])
data_36 = pd.DataFrame(data_36['data'])
data_37 = pd.DataFrame(data_37['data'])
data_38 = pd.DataFrame(data_38['data'])
data_39 = pd.DataFrame(data_39['data'])
data_40 = pd.DataFrame(data_40['data'])
data_41 = pd.DataFrame(data_41['data'])
data_42 = pd.DataFrame(data_42['data'])
data_43 = pd.DataFrame(data_43['data'])
data_44 = pd.DataFrame(data_44['data'])
data_45 = pd.DataFrame(data_45['data'])
data_46 = pd.DataFrame(data_46['data'])
data_47 = pd.DataFrame(data_47['data'])
data_48 = pd.DataFrame(data_48['data'])
data_49 = pd.DataFrame(data_49['data'])
data_50 = pd.DataFrame(data_50['data'])
data_51 = pd.DataFrame(data_51['data'])
data_52 = pd.DataFrame(data_52['data'])
data_53 = pd.DataFrame(data_53['data'])
data_54 = pd.DataFrame(data_54['data'])
data_55 = pd.DataFrame(data_55['data'])
data_56 = pd.DataFrame(data_56['data'])
data_57 = pd.DataFrame(data_57['data'])
data_58 = pd.DataFrame(data_58['data'])
data_59 = pd.DataFrame(data_59['data'])
data_60 = pd.DataFrame(data_60['data'])
data_61 = pd.DataFrame(data_61['data'])
data_62 = pd.DataFrame(data_62['data'])
data_63 = pd.DataFrame(data_63['data'])
data_64 = pd.DataFrame(data_64['data'])
data_65 = pd.DataFrame(data_65['data'])
data_66 = pd.DataFrame(data_66['data'])
data_67 = pd.DataFrame(data_67['data'])
data_68 = pd.DataFrame(data_68['data'])
data_69 = pd.DataFrame(data_69['data'])
data_70 = pd.DataFrame(data_70['data'])
data_71 = pd.DataFrame(data_71['data'])
data_72 = pd.DataFrame(data_72['data'])
data_73 = pd.DataFrame(data_73['data'])
data_74 = pd.DataFrame(data_74['data'])
data_75 = pd.DataFrame(data_75['data'])
data_76 = pd.DataFrame(data_76['data'])
data_77 = pd.DataFrame(data_77['data'])
data_78 = pd.DataFrame(data_78['data'])
data_79 = pd.DataFrame(data_79['data'])
data_80 = pd.DataFrame(data_80['data'])
data_81 = pd.DataFrame(data_81['data'])
data_82 = pd.DataFrame(data_82['data'])
data_83 = pd.DataFrame(data_83['data'])
data_84 = pd.DataFrame(data_84['data'])
data_85 = pd.DataFrame(data_85['data'])
data_86 = pd.DataFrame(data_86['data'])
data_87 = pd.DataFrame(data_87['data'])
data_88 = pd.DataFrame(data_88['data'])
data_89 = pd.DataFrame(data_89['data'])
data_90 = pd.DataFrame(data_90['data'])
data_91 = pd.DataFrame(data_91['data'])
data_92 = pd.DataFrame(data_92['data'])
data_93 = pd.DataFrame(data_93['data'])
data_94 = pd.DataFrame(data_94['data'])
data_95 = pd.DataFrame(data_95['data'])
data_96 = pd.DataFrame(data_96['data'])
data_97 = pd.DataFrame(data_97['data'])
data_98 = pd.DataFrame(data_98['data'])
data_99 = pd.DataFrame(data_99['data'])
data_100 = pd.DataFrame(data_100['data'])

# %% [markdown]
# **4. Combining all of the data**

# %%
data_October_25 = pd.concat([data_1, data_2, data_3, data_4, data_5, data_6, data_7, data_8, data_9, data_10, data_11, data_12, data_13, 
           data_14, data_15, data_16, data_17, data_18, data_19, data_20, data_21, data_22, data_23, data_24, data_25, data_26,
           data_27, data_28, data_29, data_30, data_31, data_32, data_33, data_34, data_35, data_36, data_37,
           data_38, data_39, data_40, data_41, data_42, data_43, data_44, data_45, data_46, data_47, data_48, data_49,
           data_50, data_51, data_52, data_53, data_54, data_55, data_56, data_57, data_58, data_59, data_60, data_61,
           data_62, data_63, data_64, data_65, data_66, data_67, data_68, data_69, data_70, data_71, data_72, data_73,
           data_74, data_75, data_76, data_77, data_78, data_79, data_80, data_81, data_82, data_83, data_84, data_85,
           data_86, data_87, data_88, data_89, data_90, data_91, data_92, data_93, data_94, data_95, data_96, data_97,
           data_98, data_99, data_100    
          ], axis=0)

# %% [markdown]
# **5. Renaming columns in the data**

# %%
data_October_25 = rename_column('text', 'Tweet', data_October_25)
data_October_25 = rename_column('lang', 'Language', data_October_25)
data_October_25 = rename_column('created_at', 'Date Tweeted', data_October_25)
data_October_25 = rename_column('author_id', 'Author ID', data_October_25)
data_October_25 = rename_column('id', 'ID', data_October_25)
data_October_25 = DayTweeted(data_October_25)
data_October_25 = drop(data_October_25, 'Date Tweeted')

# %% [markdown]
# **6. Dropping Duplicate Tweets**

# %%
data_October_25 = data_October_25.drop_duplicates(subset=['Tweet'])

# %% [markdown]
# **7. Converting pandas dataframe to excel file**

# %%
data_October_25.to_excel("October_25_Data.xlsx")
