# %%
import pandas as pd
import json
import os 
import glob

# %% [markdown]
# **1. Functions that will be used throughout the notebook**

# %%
def openData(path):
    with open(path) as f:
        data = json.load(f)
    return data 


def rename_column(oldName, newName, df):
    """This function renames columns of a pandas dataframe. 
    Parameters:
        oldName: Name of the old column in which you want to change 
        newName: Text in which you want the column to be renamed
        oldName2: Name of the old column in which you want to change 
        newName2: Text in which you want the column to be renamed
        df: The dataframe you want to rename columns in. 
    
    Returns a dataframe with new column names. 
    """
    New = df.rename(columns={oldName: newName})
    return New

def get_year(df):
    df["year"] = df['created_at'].astype(str).str[:4]
    return df

def drop(df, column):
    df = df.drop([column], axis=1)
    return df 

def get_month(df):
    df['Month'] = df['created_at'].str[5:7]
    return df

def get_day(df):
    df['Day'] = df['created_at'].str[8:10]
    return df

def DayTweeted(df):
    df['Date'] = df['Date Tweeted'].str[0:10]
    return df

# %% [markdown]
# **2. Calling in data from postman collected on November 1st**

# %%
data_1 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin1.json")
data_2 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin2.json")
data_3 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin3.json")
data_4 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin4.json")
data_5 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin5.json")
data_6 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin6.json")
data_7 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin7.json")
data_8 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin8.json")
data_9 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin9.json")
data_10 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin10.json")
data_11 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin11.json")
data_12 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin12.json")
data_13 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin13.json")
data_14 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin14.json")
data_15 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin15.json")
data_16 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin16.json")
data_17 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin17.json")
data_18 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin18.json")
data_19 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin19.json")
data_20 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin20.json")
data_21 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin21.json")
data_22 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin22.json")
data_23 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin23.json")
data_24 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin24.json")
data_25 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin25.json")
data_26 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin26.json")
data_27 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin27.json")
data_28 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin28.json")
data_29 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin29.json")
data_30 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 10-30/Bitcoin31.json")
data_31 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin31.json")
data_32 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin32.json")
data_33 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin33.json")
data_34 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin34.json")
data_35 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin35.json")
data_36 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin36.json")
data_37 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin37.json")
data_38 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin38.json")
data_39 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin39.json")
data_40 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitoin40.json")
data_41 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin41.json")
data_42 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin42.json")
data_43 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin43.json")
data_44 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin44.json")
data_45 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin45.json")
data_46 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin46.json")
data_47 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin47.json")
data_48 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin48.json")
data_49 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin49.json")
data_50 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin50.json")
data_51 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin51.json")
data_52 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin52.json")
data_53 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin53.json")
data_54 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin54.json")
data_55 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin55.json")
data_56 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin56.json")
data_57 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin57.json")
data_58 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin58.json")
data_59 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin59.json")
data_60 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin60.json")
data_61 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin61.json")
data_62 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin62.json")
data_63 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin63.json")
data_64 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin64.json")
data_65 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin65.json")
data_66 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin66.json")
data_67 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin67.json")
data_68 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin68.json")
data_69 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin69.json")
data_70 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin70.json")
data_71 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin71.json")
data_72 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin72.json")
data_73 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin73.json")
data_74 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin74.json")
data_75 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin75.json")
data_76 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin76.json")
data_77 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin77.json")
data_78 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin78.json")
data_79 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin79.json")
data_80 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin80.json")
data_81 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin81.json")
data_82 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin82.json")
data_83 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin83.json")
data_84 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin84.json")
data_85 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin85.json")
data_86 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin86.json")
data_87 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin87.json")
data_88 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin88.json")
data_89 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin89.json")
data_90 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin90.json")
data_91 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin91.json")
data_92 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin92.json")
data_93 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin93.json")
data_94 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin94.json")
data_95 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin95.json")
data_96 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin96.json")
data_97 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin97.json")
data_98 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin98.json")
data_99 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin99.json")
data_100 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin100.json")
data_101 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin101.json")
data_102 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin102.json")
data_103 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin103.json")
data_104 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin104.json")
data_105 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin105.json")
data_106 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin106.json")
data_107 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin107.json")
data_108 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin108.json")
data_109 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin109.json")
data_110 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin110.json")
data_111 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin111.json")
data_112 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin112.json")
data_113 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin113.json")
data_114 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin114.json")
data_115 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin115.json")
data_116 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin116.json")
data_117 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin117.json")
data_118 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin118.json")
data_119 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin119.json")
data_120 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin120.json")
data_121 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin121.json")
data_122 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin122.json")
data_123 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin123.json")
data_124 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin124.json")
data_125 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin125.json")
data_126 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin126.json")
data_127 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin127.json")
data_128 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin128.json")
data_129 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin129.json")
data_130 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 10-30/Bitcoin131.json")
data_131 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin131.json")
data_132 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin132.json")
data_133 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin133.json")
data_134 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin134.json")
data_135 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin135.json")
data_136 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin136.json")
data_137 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin137.json")
data_138 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin138.json")
data_139 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin139.json")
data_140 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin140.json")
data_141 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin141.json")
data_142 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin142.json")
data_143 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin143.json")
data_144 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin144.json")
data_145 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin145.json")
data_146 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin146.json")
data_147 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin147.json")
data_148 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin148.json")
data_149 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin149.json")
data_150 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin150.json")
data_151 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin151.json")
data_152 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin152.json")
data_153 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin153.json")
data_154 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin154.json")
data_155 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin155.json")
data_156 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin156.json")
data_157 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin157.json")
data_158 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin158.json")
data_159 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin159.json")
data_160 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin160.json")
data_161 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin161.json")
data_162 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin162.json")
data_163 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin163.json")
data_164 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin164.json")
data_165 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin165.json")
data_166 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin166.json")
data_167 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin167.json")
data_168 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin168.json")
data_169 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin169.json")
data_170 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin170.json")
data_171 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin171.json")
data_172 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin172.json")
data_173 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin173.json")
data_174 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin174.json")
data_175 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin175.json")
data_176 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin176.json")
data_177 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin177.json")
data_178 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin178.json")
data_179 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin179.json")
data_180 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin180.json")
data_181 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin181.json")
data_182 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin182.json")
data_183 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin183.json")
data_184 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin184.json")
data_185 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin185.json")
data_186 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin186.json")
data_187 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin187.json")
data_188 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin188.json")
data_189 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin189.json")
data_190 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin190.json")
data_191 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin191.json")
data_192 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin192.json")
data_193 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin193.json")
data_194 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin194.json")
data_195 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin195.json")
data_196 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin196.json")
data_197 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin197.json")
data_198 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin198.json")
data_199 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin199.json")
data_200 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin200.json")
data_201 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin201.json")
data_202 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin202.json")
data_203 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin203.json")
data_204 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin204.json")
data_205 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin205.json")
data_206 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin206.json")
data_207 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin207.json")
data_208 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin208.json")
data_209 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin209.json")
data_210 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin210.json")
data_211 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin211.json")
data_212 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin212.json")
data_213 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin213.json")
data_214 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin214.json")
data_215 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin215.json")
data_216 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin216.json")
data_217 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin217.json")
data_218 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin218.json")
data_219 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin219.json")
data_220 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin220.json")
data_221 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin221.json")
data_222 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin222.json")
data_223 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin223.json")
data_224 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin224.json")
data_225 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin225.json")
data_226 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin226.json")
data_227 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin227.json")
data_228 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin228.json")
data_229 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin229.json")
data_230 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 10-30/Bitcoin231.json")
data_231 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin231.json")
data_232 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin232.json")
data_233 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin233.json")
data_234 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin234.json")
data_235 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin235.json")
data_236 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin236.json")
data_237 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin237.json")
data_238 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin238.json")
data_239 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin239.json")
data_240 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin240.json")
data_241 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin241.json")
data_242 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin242.json")
data_243 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin243.json")
data_244 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin244.json")
data_245 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin245.json")
data_246 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin246.json")
data_247 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin247.json")
data_248 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin248.json")
data_249 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin249.json")
data_250 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin250.json")
data_251 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin251.json")
data_252 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin252.json")
data_253 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin253.json")
data_254 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin254.json")
data_255 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin255.json")
data_256 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin256.json")
data_257 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin257.json")
data_258 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin258.json")
data_259 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin259.json")
data_260 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin260.json")
data_261 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin261.json")
data_262 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin262.json")
data_263 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin263.json")
data_264 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin264.json")
data_265 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin265.json")
data_266 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin266.json")
data_267 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin267.json")
data_268 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin268.json")
data_269 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin269.json")
data_270 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin270.json")
data_271 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin271.json")
data_272 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin272.json")
data_273 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin273.json")
data_274 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin274.json")
data_275 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin275.json")
data_276 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin276.json")
data_277 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin277.json")
data_278 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin278.json")
data_279 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin279.json")
data_280 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin280.json")
data_281 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin281.json")
data_282 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin282.json")
data_283 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin283.json")
data_284 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin284.json")
data_285 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin285.json")
data_286 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin286.json")
data_287 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin287.json")
data_288 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin288.json")
data_289 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin289.json")
data_290 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin290.json")
data_291 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin291.json")
data_292 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin292.json")
data_293 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin293.json")
data_294 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin294.json")
data_295 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin295.json")
data_296 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin296.json")
data_297 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin297.json")
data_298 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin298.json")
data_299 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin299.json")
data_300 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin300.json")
data_301 = openData("/Users/jacobkuhlman/Desktop/BITCOIN DATA FINAL/Bitcoin Data 11-1/Bitcoin301.json")

# %% [markdown]
# **3. Getting just the data needed from the postman collection**

# %%
data_1 = pd.DataFrame(	data_1	['data'])
data_2 = pd.DataFrame(	data_2	['data'])
data_3 = pd.DataFrame(	data_3	['data'])
data_4 = pd.DataFrame(	data_4	['data'])
data_5 = pd.DataFrame(	data_5	['data'])
data_6 = pd.DataFrame(	data_6	['data'])
data_7 = pd.DataFrame(	data_7	['data'])
data_8 = pd.DataFrame(	data_8	['data'])
data_9 = pd.DataFrame(	data_9	['data'])
data_10= pd.DataFrame(	data_10	['data'])
data_11= pd.DataFrame(	data_11	['data'])
data_12= pd.DataFrame(	data_12	['data'])
data_13= pd.DataFrame(	data_13	['data'])
data_14= pd.DataFrame(	data_14	['data'])
data_15= pd.DataFrame(	data_15	['data'])
data_16= pd.DataFrame(	data_16	['data'])
data_17= pd.DataFrame(	data_17	['data'])
data_18= pd.DataFrame(	data_18	['data'])
data_19= pd.DataFrame(	data_19	['data'])
data_20= pd.DataFrame(	data_20	['data'])
data_21= pd.DataFrame(	data_21	['data'])
data_22= pd.DataFrame(	data_22	['data'])
data_23= pd.DataFrame(	data_23	['data'])
data_24= pd.DataFrame(	data_24	['data'])
data_25= pd.DataFrame(	data_25	['data'])
data_26= pd.DataFrame(	data_26	['data'])
data_27= pd.DataFrame(	data_27	['data'])
data_28= pd.DataFrame(	data_28	['data'])
data_29= pd.DataFrame(	data_29	['data'])
data_30= pd.DataFrame(	data_30	['data'])
data_31= pd.DataFrame(	data_31	['data'])
data_32= pd.DataFrame(	data_32	['data'])
data_33= pd.DataFrame(	data_33	['data'])
data_34= pd.DataFrame(	data_34	['data'])
data_35= pd.DataFrame(	data_35	['data'])
data_36= pd.DataFrame(	data_36	['data'])
data_37= pd.DataFrame(	data_37	['data'])
data_38= pd.DataFrame(	data_38	['data'])
data_39= pd.DataFrame(	data_39	['data'])
data_40= pd.DataFrame(	data_40	['data'])
data_41= pd.DataFrame(	data_41	['data'])
data_42= pd.DataFrame(	data_42	['data'])
data_43= pd.DataFrame(	data_43	['data'])
data_44= pd.DataFrame(	data_44	['data'])
data_45= pd.DataFrame(	data_45	['data'])
data_46= pd.DataFrame(	data_46	['data'])
data_47= pd.DataFrame(	data_47	['data'])
data_48= pd.DataFrame(	data_48	['data'])
data_49= pd.DataFrame(	data_49	['data'])
data_50= pd.DataFrame(	data_50	['data'])
data_51= pd.DataFrame(	data_51	['data'])
data_52= pd.DataFrame(	data_52	['data'])
data_53= pd.DataFrame(	data_53	['data'])
data_54= pd.DataFrame(	data_54	['data'])
data_55= pd.DataFrame(	data_55	['data'])
data_56= pd.DataFrame(	data_56	['data'])
data_57= pd.DataFrame(	data_57	['data'])
data_58= pd.DataFrame(	data_58	['data'])
data_59= pd.DataFrame(	data_59	['data'])
data_60= pd.DataFrame(	data_60	['data'])
data_61= pd.DataFrame(	data_61	['data'])
data_62= pd.DataFrame(	data_62	['data'])
data_63= pd.DataFrame(	data_63	['data'])
data_64= pd.DataFrame(	data_64	['data'])
data_65= pd.DataFrame(	data_65	['data'])
data_66= pd.DataFrame(	data_66	['data'])
data_67= pd.DataFrame(	data_67	['data'])
data_68= pd.DataFrame(	data_68	['data'])
data_69= pd.DataFrame(	data_69	['data'])
data_70= pd.DataFrame(	data_70	['data'])
data_71= pd.DataFrame(	data_71	['data'])
data_72= pd.DataFrame(	data_72	['data'])
data_73= pd.DataFrame(	data_73	['data'])
data_74= pd.DataFrame(	data_74	['data'])
data_75= pd.DataFrame(	data_75	['data'])
data_76= pd.DataFrame(	data_76	['data'])
data_77= pd.DataFrame(	data_77	['data'])
data_78= pd.DataFrame(	data_78	['data'])
data_79= pd.DataFrame(	data_79	['data'])
data_80= pd.DataFrame(	data_80	['data'])
data_81= pd.DataFrame(	data_81	['data'])
data_82= pd.DataFrame(	data_82	['data'])
data_83= pd.DataFrame(	data_83	['data'])
data_84= pd.DataFrame(	data_84	['data'])
data_85= pd.DataFrame(	data_85	['data'])
data_86= pd.DataFrame(	data_86	['data'])
data_87= pd.DataFrame(	data_87	['data'])
data_88= pd.DataFrame(	data_88	['data'])
data_89= pd.DataFrame(	data_89	['data'])
data_90= pd.DataFrame(	data_90	['data'])
data_91= pd.DataFrame(	data_91	['data'])
data_92= pd.DataFrame(	data_92	['data'])
data_93= pd.DataFrame(	data_93	['data'])
data_94= pd.DataFrame(	data_94	['data'])
data_95= pd.DataFrame(	data_95	['data'])
data_96= pd.DataFrame(	data_96	['data'])
data_97= pd.DataFrame(	data_97	['data'])
data_98= pd.DataFrame(	data_98	['data'])
data_99= pd.DataFrame(	data_99	['data'])
data_100= pd.DataFrame(	data_100	['data'])
data_101= pd.DataFrame(	data_101	['data'])
data_102= pd.DataFrame(	data_102	['data'])
data_103= pd.DataFrame(	data_103	['data'])
data_104= pd.DataFrame(	data_104	['data'])
data_105= pd.DataFrame(	data_105	['data'])
data_106= pd.DataFrame(	data_106	['data'])
data_107= pd.DataFrame(	data_107	['data'])
data_108= pd.DataFrame(	data_108	['data'])
data_109= pd.DataFrame(	data_109	['data'])
data_110= pd.DataFrame(	data_110	['data'])
data_111= pd.DataFrame(	data_111	['data'])
data_112= pd.DataFrame(	data_112	['data'])
data_113= pd.DataFrame(	data_113	['data'])
data_114= pd.DataFrame(	data_114	['data'])
data_115= pd.DataFrame(	data_115	['data'])
data_116= pd.DataFrame(	data_116	['data'])
data_117= pd.DataFrame(	data_117	['data'])
data_118= pd.DataFrame(	data_118	['data'])
data_119= pd.DataFrame(	data_119	['data'])
data_120= pd.DataFrame(	data_120	['data'])
data_121= pd.DataFrame(	data_121	['data'])
data_122= pd.DataFrame(	data_122	['data'])
data_123= pd.DataFrame(	data_123	['data'])
data_124= pd.DataFrame(	data_124	['data'])
data_125= pd.DataFrame(	data_125	['data'])
data_126= pd.DataFrame(	data_126	['data'])
data_127= pd.DataFrame(	data_127	['data'])
data_128= pd.DataFrame(	data_128	['data'])
data_129= pd.DataFrame(	data_129	['data'])
data_130= pd.DataFrame(	data_130	['data'])
data_131= pd.DataFrame(	data_131	['data'])
data_132= pd.DataFrame(	data_132	['data'])
data_133= pd.DataFrame(	data_133	['data'])
data_134= pd.DataFrame(	data_134	['data'])
data_135= pd.DataFrame(	data_135	['data'])
data_136=pd.DataFrame(	data_136	['data'])
data_137= pd.DataFrame(	data_137	['data'])
data_138= pd.DataFrame(	data_138	['data'])
data_139= pd.DataFrame(	data_139	['data'])
data_140= pd.DataFrame(	data_140	['data'])
data_141= pd.DataFrame(	data_141	['data'])
data_142= pd.DataFrame(	data_142	['data'])
data_143= pd.DataFrame(	data_143	['data'])
data_144= pd.DataFrame(	data_144	['data'])
data_145= pd.DataFrame(	data_145	['data'])
data_146= pd.DataFrame(	data_146	['data'])
data_147= pd.DataFrame(	data_147	['data'])
data_148= pd.DataFrame(	data_148	['data'])
data_149= pd.DataFrame(	data_149	['data'])
data_150= pd.DataFrame(	data_150	['data'])
data_151= pd.DataFrame(	data_151	['data'])
data_152= pd.DataFrame(	data_152	['data'])
data_153= pd.DataFrame(	data_153	['data'])
data_154= pd.DataFrame(	data_154	['data'])
data_155= pd.DataFrame(	data_155	['data'])
data_156= pd.DataFrame(	data_156	['data'])
data_157= pd.DataFrame(	data_157	['data'])
data_158= pd.DataFrame(	data_158	['data'])
data_159= pd.DataFrame(	data_159	['data'])
data_160= pd.DataFrame(	data_160	['data'])
data_161= pd.DataFrame(	data_161	['data'])
data_162= pd.DataFrame(	data_162	['data'])
data_163= pd.DataFrame(	data_163	['data'])
data_164= pd.DataFrame(	data_164	['data'])
data_165= pd.DataFrame(	data_165	['data'])
data_166= pd.DataFrame(	data_166	['data'])
data_167= pd.DataFrame(	data_167	['data'])
data_168= pd.DataFrame(	data_168	['data'])
data_169= pd.DataFrame(	data_169	['data'])
data_170= pd.DataFrame(	data_170	['data'])
data_171= pd.DataFrame(	data_171	['data'])
data_172= pd.DataFrame(	data_172	['data'])
data_173= pd.DataFrame(	data_173	['data'])
data_174= pd.DataFrame(	data_174	['data'])
data_175= pd.DataFrame(	data_175	['data'])
data_176= pd.DataFrame(	data_176	['data'])
data_177= pd.DataFrame(	data_177	['data'])
data_178= pd.DataFrame(	data_178	['data'])
data_179= pd.DataFrame(	data_179	['data'])
data_180= pd.DataFrame(	data_180	['data'])
data_181= pd.DataFrame(	data_181	['data'])
data_182= pd.DataFrame(	data_182	['data'])
data_183= pd.DataFrame(	data_183	['data'])
data_184= pd.DataFrame(	data_184	['data'])
data_185= pd.DataFrame(	data_185	['data'])
data_186= pd.DataFrame(	data_186	['data'])
data_187= pd.DataFrame(	data_187	['data'])
data_188= pd.DataFrame(	data_188	['data'])
data_189= pd.DataFrame(	data_189	['data'])
data_190= pd.DataFrame(	data_190	['data'])
data_191= pd.DataFrame(	data_191	['data'])
data_192= pd.DataFrame(	data_192	['data'])
data_193= pd.DataFrame(	data_193	['data'])
data_194= pd.DataFrame(	data_194	['data'])
data_195= pd.DataFrame(	data_195	['data'])
data_196= pd.DataFrame(	data_196	['data'])
data_197= pd.DataFrame(	data_197	['data'])
data_198= pd.DataFrame(	data_198	['data'])
data_199= pd.DataFrame(	data_199	['data'])
data_200= pd.DataFrame(	data_200	['data'])
data_201= pd.DataFrame(	data_201	['data'])
data_202= pd.DataFrame(	data_202	['data'])
data_203= pd.DataFrame(	data_203	['data'])
data_204= pd.DataFrame(	data_204	['data'])
data_205= pd.DataFrame(	data_205	['data'])
data_206= pd.DataFrame(	data_206	['data'])
data_207= pd.DataFrame(	data_207	['data'])
data_208= pd.DataFrame(	data_208	['data'])
data_209= pd.DataFrame(	data_209	['data'])
data_210= pd.DataFrame(	data_210	['data'])
data_211= pd.DataFrame(	data_211	['data'])
data_212= pd.DataFrame(	data_212	['data'])
data_213= pd.DataFrame(	data_213	['data'])
data_214= pd.DataFrame(	data_214	['data'])
data_215= pd.DataFrame(	data_215	['data'])
data_216= pd.DataFrame(	data_216	['data'])
data_217= pd.DataFrame(	data_217	['data'])
data_218= pd.DataFrame(	data_218	['data'])
data_219= pd.DataFrame(	data_219	['data'])
data_220= pd.DataFrame(	data_220	['data'])
data_221= pd.DataFrame(	data_221	['data'])
data_222= pd.DataFrame(	data_222	['data'])
data_223= pd.DataFrame(	data_223	['data'])
data_224= pd.DataFrame(	data_224	['data'])
data_225= pd.DataFrame(	data_225	['data'])
data_226= pd.DataFrame(	data_226	['data'])
data_227= pd.DataFrame(	data_227	['data'])
data_228= pd.DataFrame(	data_228	['data'])
data_229= pd.DataFrame(	data_229	['data'])
data_230= pd.DataFrame(	data_230	['data'])
data_231= pd.DataFrame(	data_231	['data'])
data_232= pd.DataFrame(	data_232	['data'])
data_233= pd.DataFrame(	data_233	['data'])
data_234= pd.DataFrame(	data_234	['data'])
data_235= pd.DataFrame(	data_235	['data'])
data_236= pd.DataFrame(	data_236	['data'])
data_237= pd.DataFrame(	data_237	['data'])
data_238= pd.DataFrame(	data_238	['data'])
data_239= pd.DataFrame(	data_239	['data'])
data_240= pd.DataFrame(	data_240	['data'])
data_241= pd.DataFrame(	data_241	['data'])
data_242= pd.DataFrame(	data_242	['data'])
data_243= pd.DataFrame(	data_243	['data'])
data_244= pd.DataFrame(	data_244	['data'])
data_245= pd.DataFrame(	data_245	['data'])
data_246= pd.DataFrame(	data_246	['data'])
data_247= pd.DataFrame(	data_247	['data'])
data_248= pd.DataFrame(	data_248	['data'])
data_249= pd.DataFrame(	data_249	['data'])
data_250= pd.DataFrame(	data_250	['data'])
data_251= pd.DataFrame(	data_251	['data'])
data_252= pd.DataFrame(	data_252	['data'])
data_253= pd.DataFrame(	data_253	['data'])
data_254= pd.DataFrame(	data_254	['data'])
data_255= pd.DataFrame(	data_255	['data'])
data_256= pd.DataFrame(	data_256	['data'])
data_257= pd.DataFrame(	data_257	['data'])
data_258= pd.DataFrame(	data_258	['data'])
data_259= pd.DataFrame(	data_259	['data'])
data_260= pd.DataFrame(	data_260	['data'])
data_261= pd.DataFrame(	data_261	['data'])
data_262= pd.DataFrame(	data_262	['data'])
data_263= pd.DataFrame(	data_263	['data'])
data_264= pd.DataFrame(	data_264	['data'])
data_265= pd.DataFrame(	data_265	['data'])
data_266= pd.DataFrame(	data_266	['data'])
data_267= pd.DataFrame(	data_267	['data'])
data_268= pd.DataFrame(	data_268	['data'])
data_269= pd.DataFrame(	data_269	['data'])
data_270= pd.DataFrame(	data_270	['data'])
data_271= pd.DataFrame(	data_271	['data'])
data_272= pd.DataFrame(	data_272	['data'])
data_273= pd.DataFrame(	data_273	['data'])
data_274= pd.DataFrame(	data_274	['data'])
data_275= pd.DataFrame(	data_275	['data'])
data_276= pd.DataFrame(	data_276	['data'])
data_277= pd.DataFrame(	data_277	['data'])
data_278= pd.DataFrame(	data_278	['data'])
data_279= pd.DataFrame(	data_279	['data'])
data_280= pd.DataFrame(	data_280	['data'])
data_281= pd.DataFrame(	data_281	['data'])
data_282= pd.DataFrame(	data_282	['data'])
data_283= pd.DataFrame(	data_283	['data'])
data_284= pd.DataFrame(	data_284	['data'])
data_285= pd.DataFrame(	data_285	['data'])
data_286= pd.DataFrame(	data_286	['data'])
data_287= pd.DataFrame(	data_287	['data'])
data_288= pd.DataFrame(	data_288	['data'])
data_289= pd.DataFrame(	data_289	['data'])
data_290= pd.DataFrame(	data_290	['data'])
data_291= pd.DataFrame(	data_291	['data'])
data_292= pd.DataFrame(	data_292	['data'])
data_293= pd.DataFrame(	data_293	['data'])
data_294= pd.DataFrame(	data_294	['data'])
data_295= pd.DataFrame(	data_295	['data'])
data_296= pd.DataFrame(	data_296	['data'])
data_297= pd.DataFrame(	data_297	['data'])
data_298= pd.DataFrame(	data_298	['data'])
data_299= pd.DataFrame(	data_299	['data'])
data_300= pd.DataFrame(	data_300	['data'])
data_301= pd.DataFrame(	data_301	['data'])

# %% [markdown]
# **4. Combining all of the data**

# %%
data_November_1 = pd.concat([data_1, data_2, data_3, data_4, data_5, data_6, data_7, data_8, data_9, data_10, data_11, data_12, data_13, 
           data_14, data_15, data_16, data_17, data_18, data_19, data_20, data_21, data_22, data_23, data_24, data_25, data_26,
           data_27, data_28, data_29, data_30, data_31, data_32, data_33, data_34, data_35, data_36, data_37,
           data_38, data_39, data_40, data_41, data_42, data_43, data_44, data_45, data_46, data_47, data_48, data_49,
           data_50, data_51, data_52, data_53, data_54, data_55, data_56, data_57, data_58, data_59, data_60, data_61,data_62,
           data_63, data_64, data_65, data_66, data_67, data_68, data_69, data_70, data_71, data_72, data_73,
           data_74, data_75, data_76, data_77, data_78, data_79, data_80, data_81, data_82, data_83, data_84, data_85,
           data_86, data_87, data_88, data_89, data_89, data_90, data_91, data_92, data_93, data_94, data_95, data_96, data_97, data_98, data_99, data_100, data_101, data_102, data_103,
           data_104, data_105, data_106, data_107, data_108,data_109,data_110,data_111,data_112,data_113,data_114,data_115,data_116,data_117,data_118,data_119,
           data_120,data_121,data_122,data_123,data_24,data_125,data_126,data_27,data_128,data_129,data_130,data_131, data_132,data_133,data_134,data_135,data_136,data_137,data_138, 
           data_139,data_140,data_141,data_142,data_143,data_144,data_145,data_146,data_147,data_148, data_149,data_150,data_151,data_152,data_153,data_154,data_155,data_156, data_157,data_158,data_159,
           data_160,data_161,data_162,data_163,data_164,data_165,data_166,data_167,data_168,data_169,data_170,data_171,data_172,data_173,data_174,data_175,data_176,data_177,data_178,data_179,data_180,data_181,data_182,data_183,data_184,data_185,data_186,data_187,data_188,data_189,data_190,data_191,data_192,data_193,data_194,data_195,
           data_196,data_197,data_198,data_199,data_200,data_201,data_202,data_203,data_204,data_205,data_206,data_207,data_208,data_209,data_210,data_211,data_212,data_213,data_214,data_215,
           data_216,data_217, data_218,data_219,data_220,data_221,data_222,data_223,data_224,data_225,data_226,data_227,data_228,data_229,data_230,data_231, data_232,data_233,data_234,data_235,data_236,data_237,
           data_238,data_239,data_240,data_241,data_242,data_243,data_244,data_245,data_246,data_247,data_248,data_249,data_250,data_251,data_252,data_253,data_254,data_255,data_256,data_257,data_258,data_259,data_260,data_261,data_262,data_263,data_264,
           data_265, data_266,data_267,data_268,data_269,data_270,data_271,data_272,data_273,data_274,data_275,data_276,data_277,data_278,data_279,data_280,data_281,data_282,data_283,
           data_284,data_285,data_286,data_287,data_288,data_289,data_290,data_291,data_292,data_293,data_294,data_295,data_296,data_297,data_298,data_299, data_300, data_301
                             
          ], axis=0)

# %% [markdown]
# **5. Renaming columns in the data**

# %%
data_November_1 = rename_column('text', 'Tweet', data_November_1)
data_November_1 = rename_column('lang', 'Language', data_November_1)
data_November_1 = rename_column('created_at', 'Date Tweeted', data_November_1)
data_November_1 = rename_column('author_id', 'Author ID', data_November_1)
data_November_1 = rename_column('id', 'ID', data_November_1)
data_November_1 = DayTweeted(data_November_1)
data_November_1 = drop(data_November_1, 'Date Tweeted')

# %% [markdown]
# **6. Dropping Duplicate Tweets**

# %%
data_November_1 = data_November_1.drop_duplicates(subset=['Tweet'])

# %% [markdown]
# **7. Converting pandas dataframe to excel file**

# %%
data_November_1.to_excel("November_1_Data.xlsx")
